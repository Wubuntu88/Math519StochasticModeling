# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import re
import seaborn as sns
sns.set(style="darkgrid")
from scipy import stats
import matplotlib.patches as mpatches

# %%
data_types = {'Recall Notification Date': str}
df = pd.read_csv("database.csv", dtype=data_types)

# %%
df.dtypes
# Out:
# Record ID                     int64
# NHTSA Campaign               object
# Manufacturer Campaign        object
# Vehicle Make                 object
# Vehicle Model                object
# Model Year                    int64
# Vehicle Manufacturer         object
# Recall Type                  object
# Recall Component             object
# Manufacture Start Date      float64
# Manufacture End Date        float64
# Estimated Units             float64
# Recall Initiative            object
# Recall Manufacturer          object
# Recall Notification Date     object
# dtype: object

# %%
ford_aliases = {
    'FORD MOTOR COMPANY',
    'FORD MOTOR COMPANY test adw as',
    'FORD MTR CO-OVERSEAS',
    'Ford Motor Company'
}

# %%
ford_df = df.loc[df['Vehicle Manufacturer'].isin(ford_aliases)]

# %%
ford_df_over_500k = ford_df.loc[df['Estimated Units'] > 500000.0]

# %%
len(ford_df_over_500k)
# Out:
# 1145

# %%
ford_df_filtered = ford_df_over_500k.dropna(subset=['Recall Notification Date'])

# %%
ford_df_filtered_with_date = ford_df_filtered['Recall Notification Date'].apply(lambda x:pd.datetime.strptime(x, '%Y%m%d'))

# %%
type(ford_df_filtered['Estimated Units'])
# Out:
# pandas.core.series.Series

# %%
ford_df_filtered
# Out:
#         Record ID NHTSA Campaign Manufacturer Campaign Vehicle Make  \
# 2036         2037      01V261000                 01S25         FORD
# 2037         2038      01V261000                 01S25         FORD
# 2038         2039      01V261000                 01S25         FORD
# 2389         2390      01V390000                 01S30      MERCURY
# 2390         2391      01V390000                 01S30         FORD
# 2391         2392      01V390000                 01S30         FORD
# 2477         2478      01V258000                 01S24         FORD
# 2478         2479      01V258000                 01S24         FORD
# 2479         2480      01V258000                 01S24         FORD
# 2480         2481      01V258000                 01S24         FORD
# 2481         2482      01V258000                 01S24         FORD
# 2482         2483      01V258000                 01S24         FORD
# 2483         2484      01V258000                 01S24         FORD
# 2484         2485      01V258000                 01S24         FORD
# 2485         2486      01V258000                 01S24         FORD
# 2486         2487      01V258000                 01S24         FORD
# 2487         2488      01V258000                 01S24      LINCOLN
# 2488         2489      01V258000                 01S24      LINCOLN
# 2489         2490      01V258000                 01S24      LINCOLN
# 2490         2491      01V258000                 01S24      LINCOLN
# 2491         2492      01V258000                 01S24         FORD
# 2492         2493      01V258000                 01S24         FORD
# 2493         2494      01V258000                 01S24         FORD
# 2494         2495      01V258000                 01S24         FORD
# 2495         2496      01V258000                 01S24      LINCOLN
# 2496         2497      01V258000                 01S24      LINCOLN
# 2497         2498      01V258000                 01S24      MERCURY
# 2498         2499      01V258000                 01S24      MERCURY
# 2499         2500      01V258000                 01S24         FORD
# 2500         2501      01V258000                 01S24         FORD
# ...           ...            ...                   ...          ...
# 107282     107283      15V319000                 15S21         FORD
# 107283     107284      15V319000                 15S21         FORD
# 107284     107285      15V319000                 15S21         FORD
# 107285     107286      15V319000                 15S21         FORD
# 107286     107287      15V319000                 15S21         FORD
# 107287     107288      15V319000                 15S21         FORD
# 118557     118558      14V597000                 14S21         FORD
# 118558     118559      14V597000                 14S21         FORD
# 118559     118560      14V597000                 14S21         FORD
# 118560     118561      14V597000                 14S21      LINCOLN
# 118561     118562      14V597000                 14S21      LINCOLN
# 118562     118563      14V597000                 14S21      LINCOLN
# 118563     118564      14V597000                 14S21         FORD
# 118564     118565      14V597000                 14S21         FORD
# 118565     118566      14V597000                 14S21         FORD
# 118566     118567      14V597000                 14S21         FORD
# 118567     118568      14V597000                 14S21         FORD
# 118568     118569      14V597000                 14S21         FORD
# 118569     118570      14V597000                 14S21         FORD
# 118570     118571      14V597000                 14S21         FORD
# 118571     118572      14V597000                 14S21         FORD
# 118572     118573      14V597000                 14S21         FORD
# 118573     118574      14V597000                 14S21         FORD
# 118574     118575      14V597000                 14S21         FORD
# 118575     118576      14V597000                 14S21      LINCOLN
# 118576     118577      14V597000                 14S21      LINCOLN
# 118577     118578      14V597000                 14S21      LINCOLN
# 118578     118579      14V597000                 14S21         FORD
# 118579     118580      14V597000                 14S21         FORD
# 118580     118581      14V597000                 14S21         FORD
#
#        Vehicle Model  Model Year Vehicle Manufacturer Recall Type  \
# 2036        WINDSTAR        2001   FORD MOTOR COMPANY     VEHICLE
# 2037        WINDSTAR        2000   FORD MOTOR COMPANY     VEHICLE
# 2038        WINDSTAR        1999   FORD MOTOR COMPANY     VEHICLE
# 2389           SABLE        1995   FORD MOTOR COMPANY     VEHICLE
# 2390          TAURUS        1995   FORD MOTOR COMPANY     VEHICLE
# 2391         MUSTANG        1995   FORD MOTOR COMPANY     VEHICLE
# 2477        F-550 SD        2000   FORD MOTOR COMPANY     VEHICLE
# 2478        F-550 SD        2001   FORD MOTOR COMPANY     VEHICLE
# 2479        F-450 SD        2001   FORD MOTOR COMPANY     VEHICLE
# 2480        F-450 SD        2000   FORD MOTOR COMPANY     VEHICLE
# 2481          TAURUS        2001   FORD MOTOR COMPANY     VEHICLE
# 2482          TAURUS        2000   FORD MOTOR COMPANY     VEHICLE
# 2483           FOCUS        2001   FORD MOTOR COMPANY     VEHICLE
# 2484           FOCUS        2000   FORD MOTOR COMPANY     VEHICLE
# 2485           F-150        2001   FORD MOTOR COMPANY     VEHICLE
# 2486           F-150        2000   FORD MOTOR COMPANY     VEHICLE
# 2487        TOWN CAR        2001   FORD MOTOR COMPANY     VEHICLE
# 2488        TOWN CAR        2000   FORD MOTOR COMPANY     VEHICLE
# 2489       NAVIGATOR        2001   FORD MOTOR COMPANY     VEHICLE
# 2490       NAVIGATOR        2000   FORD MOTOR COMPANY     VEHICLE
# 2491       EXCURSION        2001   FORD MOTOR COMPANY     VEHICLE
# 2492       EXCURSION        2000   FORD MOTOR COMPANY     VEHICLE
# 2493      EXPEDITION        2001   FORD MOTOR COMPANY     VEHICLE
# 2494      EXPEDITION        2000   FORD MOTOR COMPANY     VEHICLE
# 2495     CONTINENTAL        2001   FORD MOTOR COMPANY     VEHICLE
# 2496     CONTINENTAL        2000   FORD MOTOR COMPANY     VEHICLE
# 2497           SABLE        2001   FORD MOTOR COMPANY     VEHICLE
# 2498           SABLE        2000   FORD MOTOR COMPANY     VEHICLE
# 2499            F750        2000   FORD MOTOR COMPANY     VEHICLE
# 2500           F-650        2000   FORD MOTOR COMPANY     VEHICLE
# ...              ...         ...                  ...         ...
# 107282       MUSTANG        2009   Ford Motor Company     VEHICLE
# 107283       MUSTANG        2008   Ford Motor Company     VEHICLE
# 107284       MUSTANG        2005   Ford Motor Company     VEHICLE
# 107285       MUSTANG        2006   Ford Motor Company     VEHICLE
# 107286       MUSTANG        2007   Ford Motor Company     VEHICLE
# 107287            GT        2005   Ford Motor Company     VEHICLE
# 118557         C-MAX        2013   Ford Motor Company     VEHICLE
# 118558         C-MAX        2013   Ford Motor Company     VEHICLE
# 118559         C-MAX        2013   Ford Motor Company     VEHICLE
# 118560           MKZ        2014   Ford Motor Company     VEHICLE
# 118561           MKZ        2014   Ford Motor Company     VEHICLE
# 118562           MKZ        2014   Ford Motor Company     VEHICLE
# 118563        FUSION        2014   Ford Motor Company     VEHICLE
# 118564        FUSION        2014   Ford Motor Company     VEHICLE
# 118565        FUSION        2014   Ford Motor Company     VEHICLE
# 118566         C-MAX        2014   Ford Motor Company     VEHICLE
# 118567         C-MAX        2014   Ford Motor Company     VEHICLE
# 118568         C-MAX        2014   Ford Motor Company     VEHICLE
# 118569        ESCAPE        2014   Ford Motor Company     VEHICLE
# 118570        ESCAPE        2014   Ford Motor Company     VEHICLE
# 118571        ESCAPE        2014   Ford Motor Company     VEHICLE
# 118572        FUSION        2013   Ford Motor Company     VEHICLE
# 118573        FUSION        2013   Ford Motor Company     VEHICLE
# 118574        FUSION        2013   Ford Motor Company     VEHICLE
# 118575           MKZ        2013   Ford Motor Company     VEHICLE
# 118576           MKZ        2013   Ford Motor Company     VEHICLE
# 118577           MKZ        2013   Ford Motor Company     VEHICLE
# 118578        ESCAPE        2013   Ford Motor Company     VEHICLE
# 118579        ESCAPE        2013   Ford Motor Company     VEHICLE
# 118580        ESCAPE        2013   Ford Motor Company     VEHICLE
#
#                                     Recall Component  Manufacture Start Date  \
# 2036        VISIBILITY:WINDSHIELD WIPER/WASHER:MOTOR              19980416.0
# 2037        VISIBILITY:WINDSHIELD WIPER/WASHER:MOTOR              19980416.0
# 2038        VISIBILITY:WINDSHIELD WIPER/WASHER:MOTOR              19980416.0
# 2389    ENGINE AND ENGINE COOLING:COOLING SYSTEM:FAN              19940413.0
# 2390    ENGINE AND ENGINE COOLING:COOLING SYSTEM:FAN              19940413.0
# 2391    ENGINE AND ENGINE COOLING:COOLING SYSTEM:FAN              19940413.0
# 2477        VISIBILITY:WINDSHIELD WIPER/WASHER:MOTOR                     NaN
# 2478        VISIBILITY:WINDSHIELD WIPER/WASHER:MOTOR                     NaN
# 2479        VISIBILITY:WINDSHIELD WIPER/WASHER:MOTOR                     NaN
# 2480        VISIBILITY:WINDSHIELD WIPER/WASHER:MOTOR                     NaN
# 2481        VISIBILITY:WINDSHIELD WIPER/WASHER:MOTOR                     NaN
# 2482        VISIBILITY:WINDSHIELD WIPER/WASHER:MOTOR                     NaN
# 2483        VISIBILITY:WINDSHIELD WIPER/WASHER:MOTOR                     NaN
# 2484        VISIBILITY:WINDSHIELD WIPER/WASHER:MOTOR                     NaN
# 2485        VISIBILITY:WINDSHIELD WIPER/WASHER:MOTOR                     NaN
# 2486        VISIBILITY:WINDSHIELD WIPER/WASHER:MOTOR                     NaN
# 2487        VISIBILITY:WINDSHIELD WIPER/WASHER:MOTOR                     NaN
# 2488        VISIBILITY:WINDSHIELD WIPER/WASHER:MOTOR                     NaN
# 2489        VISIBILITY:WINDSHIELD WIPER/WASHER:MOTOR                     NaN
# 2490        VISIBILITY:WINDSHIELD WIPER/WASHER:MOTOR                     NaN
# 2491        VISIBILITY:WINDSHIELD WIPER/WASHER:MOTOR                     NaN
# 2492        VISIBILITY:WINDSHIELD WIPER/WASHER:MOTOR                     NaN
# 2493        VISIBILITY:WINDSHIELD WIPER/WASHER:MOTOR                     NaN
# 2494        VISIBILITY:WINDSHIELD WIPER/WASHER:MOTOR                     NaN
# 2495        VISIBILITY:WINDSHIELD WIPER/WASHER:MOTOR                     NaN
# 2496        VISIBILITY:WINDSHIELD WIPER/WASHER:MOTOR                     NaN
# 2497        VISIBILITY:WINDSHIELD WIPER/WASHER:MOTOR                     NaN
# 2498        VISIBILITY:WINDSHIELD WIPER/WASHER:MOTOR                     NaN
# 2499        VISIBILITY:WINDSHIELD WIPER/WASHER:MOTOR                     NaN
# 2500        VISIBILITY:WINDSHIELD WIPER/WASHER:MOTOR                     NaN
# ...                                              ...                     ...
# 107282  AIR BAGS:FRONTAL:DRIVER SIDE INFLATOR MODULE              20040406.0
# 107283  AIR BAGS:FRONTAL:DRIVER SIDE INFLATOR MODULE              20040406.0
# 107284  AIR BAGS:FRONTAL:DRIVER SIDE INFLATOR MODULE              20040406.0
# 107285  AIR BAGS:FRONTAL:DRIVER SIDE INFLATOR MODULE              20040406.0
# 107286  AIR BAGS:FRONTAL:DRIVER SIDE INFLATOR MODULE              20040406.0
# 107287  AIR BAGS:FRONTAL:DRIVER SIDE INFLATOR MODULE              20040220.0
# 118557                                      AIR BAGS              20120119.0
# 118558                          AIR BAGS:SIDE/WINDOW              20120119.0
# 118559                                    SEAT BELTS              20120119.0
# 118560                                      AIR BAGS              20120425.0
# 118561                          AIR BAGS:SIDE/WINDOW              20120425.0
# 118562                                    SEAT BELTS              20120425.0
# 118563                                      AIR BAGS              20120203.0
# 118564                          AIR BAGS:SIDE/WINDOW              20120203.0
# 118565                                    SEAT BELTS              20120203.0
# 118566                                      AIR BAGS              20120119.0
# 118567                          AIR BAGS:SIDE/WINDOW              20120119.0
# 118568                                    SEAT BELTS              20120119.0
# 118569                                      AIR BAGS              20111005.0
# 118570                          AIR BAGS:SIDE/WINDOW              20111005.0
# 118571                                    SEAT BELTS              20111005.0
# 118572                                      AIR BAGS              20120203.0
# 118573                          AIR BAGS:SIDE/WINDOW              20120203.0
# 118574                                    SEAT BELTS              20120203.0
# 118575                                      AIR BAGS              20120425.0
# 118576                          AIR BAGS:SIDE/WINDOW              20120425.0
# 118577                                    SEAT BELTS              20120425.0
# 118578                                      AIR BAGS              20111005.0
# 118579                          AIR BAGS:SIDE/WINDOW              20111005.0
# 118580                                    SEAT BELTS              20111005.0
#
#         Manufacture End Date  Estimated Units Recall Initiative  \
# 2036              20010602.0         598256.0               MFR
# 2037              20010602.0         598256.0               MFR
# 2038              20010602.0         598256.0               MFR
# 2389              19950811.0         695260.0               MFR
# 2390              19950811.0         695260.0               MFR
# 2391              19950811.0         695260.0               MFR
# 2477                     NaN        1083000.0               MFR
# 2478                     NaN        1083000.0               MFR
# 2479                     NaN        1083000.0               MFR
# 2480                     NaN        1083000.0               MFR
# 2481                     NaN        1083000.0               MFR
# 2482                     NaN        1083000.0               MFR
# 2483                     NaN        1083000.0               MFR
# 2484                     NaN        1083000.0               MFR
# 2485                     NaN        1083000.0               MFR
# 2486                     NaN        1083000.0               MFR
# 2487                     NaN        1083000.0               MFR
# 2488                     NaN        1083000.0               MFR
# 2489                     NaN        1083000.0               MFR
# 2490                     NaN        1083000.0               MFR
# 2491                     NaN        1083000.0               MFR
# 2492                     NaN        1083000.0               MFR
# 2493                     NaN        1083000.0               MFR
# 2494                     NaN        1083000.0               MFR
# 2495                     NaN        1083000.0               MFR
# 2496                     NaN        1083000.0               MFR
# 2497                     NaN        1083000.0               MFR
# 2498                     NaN        1083000.0               MFR
# 2499                     NaN        1083000.0               MFR
# 2500                     NaN        1083000.0               MFR
# ...                      ...              ...               ...
# 107282            20140621.0        1018622.0               ODI
# 107283            20140621.0        1018622.0               ODI
# 107284            20140621.0        1018622.0               ODI
# 107285            20140621.0        1018622.0               ODI
# 107286            20140621.0        1018622.0               ODI
# 107287            20060922.0        1018622.0               ODI
# 118557            20131121.0         746842.0               MFR
# 118558            20131121.0         746842.0               MFR
# 118559            20131121.0         746842.0               MFR
# 118560            20130930.0         746842.0               MFR
# 118561            20130930.0         746842.0               MFR
# 118562            20130930.0         746842.0               MFR
# 118563            20130824.0         746842.0               MFR
# 118564            20130824.0         746842.0               MFR
# 118565            20130824.0         746842.0               MFR
# 118566            20131121.0         746842.0               MFR
# 118567            20131121.0         746842.0               MFR
# 118568            20131121.0         746842.0               MFR
# 118569            20131101.0         746842.0               MFR
# 118570            20131101.0         746842.0               MFR
# 118571            20131101.0         746842.0               MFR
# 118572            20130824.0         746842.0               MFR
# 118573            20130824.0         746842.0               MFR
# 118574            20130824.0         746842.0               MFR
# 118575            20130930.0         746842.0               MFR
# 118576            20130930.0         746842.0               MFR
# 118577            20130930.0         746842.0               MFR
# 118578            20131101.0         746842.0               MFR
# 118579            20131101.0         746842.0               MFR
# 118580            20131101.0         746842.0               MFR
#
#        Recall Manufacturer Recall Notification Date
# 2036    FORD MOTOR COMPANY                 20010827
# 2037    FORD MOTOR COMPANY                 20010827
# 2038    FORD MOTOR COMPANY                 20010827
# 2389    FORD MOTOR COMPANY                 20021228
# 2390    FORD MOTOR COMPANY                 20021228
# 2391    FORD MOTOR COMPANY                 20021228
# 2477    FORD MOTOR COMPANY                 20010820
# 2478    FORD MOTOR COMPANY                 20010820
# 2479    FORD MOTOR COMPANY                 20010820
# 2480    FORD MOTOR COMPANY                 20010820
# 2481    FORD MOTOR COMPANY                 20010820
# 2482    FORD MOTOR COMPANY                 20010820
# 2483    FORD MOTOR COMPANY                 20010820
# 2484    FORD MOTOR COMPANY                 20010820
# 2485    FORD MOTOR COMPANY                 20010820
# 2486    FORD MOTOR COMPANY                 20010820
# 2487    FORD MOTOR COMPANY                 20010820
# 2488    FORD MOTOR COMPANY                 20010820
# 2489    FORD MOTOR COMPANY                 20010820
# 2490    FORD MOTOR COMPANY                 20010820
# 2491    FORD MOTOR COMPANY                 20010820
# 2492    FORD MOTOR COMPANY                 20010820
# 2493    FORD MOTOR COMPANY                 20010820
# 2494    FORD MOTOR COMPANY                 20010820
# 2495    FORD MOTOR COMPANY                 20010820
# 2496    FORD MOTOR COMPANY                 20010820
# 2497    FORD MOTOR COMPANY                 20010820
# 2498    FORD MOTOR COMPANY                 20010820
# 2499    FORD MOTOR COMPANY                 20010820
# 2500    FORD MOTOR COMPANY                 20010820
# ...                    ...                      ...
# 107282  FORD MOTOR COMPANY                 20160610
# 107283  FORD MOTOR COMPANY                 20160610
# 107284  FORD MOTOR COMPANY                 20160610
# 107285  FORD MOTOR COMPANY                 20160610
# 107286  FORD MOTOR COMPANY                 20160610
# 107287  FORD MOTOR COMPANY                 20160610
# 118557  FORD MOTOR COMPANY                 20150526
# 118558  FORD MOTOR COMPANY                 20150526
# 118559  FORD MOTOR COMPANY                 20150526
# 118560  FORD MOTOR COMPANY                 20150526
# 118561  FORD MOTOR COMPANY                 20150526
# 118562  FORD MOTOR COMPANY                 20150526
# 118563  FORD MOTOR COMPANY                 20150526
# 118564  FORD MOTOR COMPANY                 20150526
# 118565  FORD MOTOR COMPANY                 20150526
# 118566  FORD MOTOR COMPANY                 20150526
# 118567  FORD MOTOR COMPANY                 20150526
# 118568  FORD MOTOR COMPANY                 20150526
# 118569  FORD MOTOR COMPANY                 20150526
# 118570  FORD MOTOR COMPANY                 20150526
# 118571  FORD MOTOR COMPANY                 20150526
# 118572  FORD MOTOR COMPANY                 20150526
# 118573  FORD MOTOR COMPANY                 20150526
# 118574  FORD MOTOR COMPANY                 20150526
# 118575  FORD MOTOR COMPANY                 20150526
# 118576  FORD MOTOR COMPANY                 20150526
# 118577  FORD MOTOR COMPANY                 20150526
# 118578  FORD MOTOR COMPANY                 20150526
# 118579  FORD MOTOR COMPANY                 20150526
# 118580  FORD MOTOR COMPANY                 20150526
#
# [993 rows x 15 columns]

# %%
date_split_value = pd.datetime(1995, 1, 1) # ignore values before 1995

# %%
recalls_by_units_df = pd.DataFrame({
        'Recall Notification Date': ford_df_filtered_with_date,
        'Estimated Units': ford_df_filtered['Estimated Units']
})

# %%
recalls_by_units_df_after_1995 = recalls_by_units_df.loc[recalls_by_units_df['Recall Notification Date'] > date_split_value]

# %%
recalls_by_unit_after_1995_unique = recalls_by_units_df_after_1995.drop_duplicates()

# %%
ford_stock_data_types = {
    'Date': str,
    'Price': float
}
ford_stock = pd.read_csv('zstock_data_clean/ford_stock.txt', sep='\t', parse_dates=['Date'])

# %%
ford_stock_after_1995 = ford_stock.loc[ford_stock['Date'] > date_split_value]

# %%
plt.plot(list(ford_stock_after_1995['Date']), list(ford_stock_after_1995['Price']))
#plt.scatter(list(recalls_by_unit_after_1995_unique['Recall Notification Date']), [25 for x in range(0, len(recalls_by_unit_after_1995_unique))])
#for i in range(0, len(recalls_by_unit_after_1995_unique))
#    plt.plot([, ])
my_dates_list = list(recalls_by_unit_after_1995_unique['Recall Notification Date'])
plt.vlines(x=my_dates_list, ymin=[0 for x in range(0, len(my_dates_list))], ymax=[25 for x in range(0, len(my_dates_list))])
plt.title('Ford Stock', fontsize=20)
plt.xlabel('Time', fontsize=16)
plt.ylabel('Stock Price', fontsize=16)
black_patch = mpatches.Patch(color='black', label='recalls > 500k units')
plt.legend(handles=[black_patch],
           loc='upper right')
plt.show()

# %%
ford_stock_after_1995_reset_indices = ford_stock_after_1995.reset_index()
ford_stock_after_1995_reset_indices.drop('index', axis=1, inplace=True)

# %%
# now we will conduct the event study
dates_arr = np.array(ford_stock_after_1995_reset_indices['Date'])
prices_arr = np.array(ford_stock_after_1995_reset_indices['Price'])
recalls_dates_arr = np.array(recalls_by_unit_after_1995_unique['Recall Notification Date'])

# %%
np.argwhere(dates_arr == recalls_dates_arr[0])[0][0]
# Out:
# 1679

# %%
indices_recalls_in_stocks_arrays = []
for recall_date in recalls_dates_arr:
    idx = np.argwhere(dates_arr == recall_date)
    while(len(idx) != 1):
        recall_date -= np.timedelta64(1,'D')
        idx = np.argwhere(dates_arr == recall_date)
    assert len(idx) == 1
    indices_recalls_in_stocks_arrays.append(idx[0][0])
indices_recalls_in_stocks_arrays = np.array(indices_recalls_in_stocks_arrays)
#indices_recalls_in_stocks_arrays

# %%
# must get stock prices for 10 days previous, take diff of today - (today - 10 days), then do paired t test to see 
# if diff is different from 0
days_from_recall = 10
indices_of_recalls_minus_ten_days = indices_recalls_in_stocks_arrays - days_from_recall
indices_of_recalls_plus_ten_days = indices_recalls_in_stocks_arrays + days_from_recall

# %%
assert len(indices_of_recalls_minus_ten_days) == len(indices_recalls_in_stocks_arrays)
stock_price_differences = [] # price on event - price before event
for i in range(0, len(indices_recalls_in_stocks_arrays)):
    before_price = prices_arr[indices_of_recalls_minus_ten_days[i]]
    after_price = prices_arr[indices_of_recalls_plus_ten_days[i]]
    on_event_price = prices_arr[indices_recalls_in_stocks_arrays[i]]
    #diff = on_event_price - before_price
    diff = after_price - on_event_price
    stock_price_differences.append(diff)
stock_price_differences = np.array(stock_price_differences)

# %%
from scipy import stats

# %%
the_t_statistic, the_p_value = stats.ttest_1samp(a=stock_price_differences, popmean=0)
print('t stat:', "{:.3f}".format(the_t_statistic), 'p value:', "{:.3f}".format(the_p_value))
# Out:
# t stat: -2.320 p value: 0.025

# %%
plt.hist(stock_price_differences)
#plt.title('Pre-recall Differences\nt_stat: {:.3f}, p value: {:.3f}'.format(the_t_statistic, the_p_value), fontsize=20)
plt.title('Post-recall Differences\nt_stat: {:.3f}, p value: {:.3f}'.format(the_t_statistic, the_p_value), fontsize=20)
plt.xlabel('Difference', fontsize=16)
plt.ylabel('Count', fontsize=16)
plt.show()
